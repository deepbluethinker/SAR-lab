# %% [markdown]
# ##  奈奎斯特采样率
#
# 原文链接：https://blog.csdn.net/a619398297/article/details/110090784

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体 
plt.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
f0 = 300;  #% 连续正弦波 频率
fs = 800;  #% 抽样频率
Ts = 1/fs;

N  = 8;#%抽样点数N

#% 设置原信号
t1  = np.linspace( 0, (N-1)*Ts, 501 );
ft1 = np.sin( 2*np.pi*f0*t1 );

#% 用800Hz抽样
t2  = np.arange(0,N,1)*Ts;
ft2 = np.sin( 2*np.pi*f0*t2 );


#%% 以400Hz抽样300Hz的信号
#% 参数设置
f0 = 300;  #% 连续正弦波 频率
fs = 400;  #% 抽样频率
Ts = 1/fs;
M  = 5;#% 总抽样点数N

#% 设置原信号
t1_1  = np.linspace( 0, (M-1)*Ts, 201 );
ft1_1 = np.sin( 2*np.pi*f0*t1_1 );

#% 以400Hz抽样
t2_2  = np.arange(0,M,1)*Ts+Ts/3;
ft2_2 = np.sin( 2*np.pi*f0*t2_2 );

# %%
#画图
plt.figure()
plt.plot( t1_1, ft1_1, 'r', t2_2, ft2_2, 'ko',t2, ft2, '--')
plt.xlabel('t')
plt.legend( ['300Hz连续信号'], ['原信号以400Hz抽样'],['原信号以800Hz抽样'])
plt.title( '频率为f0的信号以fs抽样（fs<2*f0）')
plt.axis([0,0.01,-1,1]);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36228/3855939553.py in <module>
#       3 plt.plot( t1_1, ft1_1, 'r', t2_2, ft2_2, 'ko',t2, ft2, '--')
#       4 plt.xlabel('t')
# ----> 5 plt.legend( ['300Hz连续信号'], ['原信号以400Hz抽样'],['原信号以800Hz抽样'])
#       6 plt.title( '频率为f0的信号以fs抽样（fs<2*f0）')
#       7 plt.axis([0,0.01,-1,1]);
#
# d:\anaconda3\envs\stock\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    2653 @_copy_docstring_and_deprecators(Axes.legend)
#    2654 def legend(*args, **kwargs):
# -> 2655     return gca().legend(*args, **kwargs)
#    2656
#    2657
#
# d:\anaconda3\envs\stock\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     302                 **kwargs)
#     303         if len(extra_args):
# --> 304             raise TypeError('legend only accepts two non-keyword arguments')
#     305         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     306         self.legend_._remove_method = self._remove_legend
#
# TypeError: legend only accepts two non-keyword arguments
