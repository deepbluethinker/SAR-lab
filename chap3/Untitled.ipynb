# %%
https://zhuanlan.zhihu.com/p/395849685

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体 
plt.rcParams.update({"font.size":20})#此处必须添加此句代码方可改变标题字体大小
plt.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
# clc;clear all;close all;
# %% 参数设置
T = 20e-3;                         # %脉宽
B = 20e3;                          # %信号带宽
K = B/T;                           # %调频斜率
Fs = 2*B;Ts = 1/Fs;                # %采样频率及采样间隔
N = int(np.round(T/Ts));
t = np.linspace(-T/2,T/2,N);

# %% LFM信号产生
St = np.exp(1j*np.pi*K*t**2);         #    %生成线性调频信号
plt.figure(figsize=(20,10));
plt.subplot(311)
plt.plot(t*1e3,np.real(St));
plt.xlabel('时间/ms');plt.ylabel('信号幅度');
plt.title('线性调频信号');
plt.grid( )
plt.subplot(312)
freq = np.linspace(-Fs/2,Fs/2,N);
Fw=np.fft.fftshift(np.fft.fft(St));
plt.plot(freq*1e-3,np.abs(Fw));
plt.xlabel('频率/KHz');plt.ylabel('信号幅度');
plt.title('线性调频信号的幅-频特性');
plt.grid();
plt.subplot(313)
freq = np.linspace(-Fs/2,Fs/2,N);
Fw=np.fft.fftshift(np.fft.fft(St));
plt.plot(freq*1e-3,np.angle(Fw));
plt.xlabel('频率/KHz');plt.ylabel('信号相位');
plt.title('线性调频信号的相-频特性');
plt.grid();
#set(gcf,'name','LFM信号时频域显示','Numbertitle','off')
plt.tight_layout()
